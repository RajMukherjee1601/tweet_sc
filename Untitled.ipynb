# %%
import snscrape.modules.twitter as sntwitter

# Define the keyword to search for
keyword = 'Ramsri Goutham Golla'

# Search for tweets containing the keyword
tweets = sntwitter.TwitterSearchScraper(f'{keyword} lang:en').get_items()

# Print the text of each tweet
for tweet in tweets:
    print(tweet.content)
# Out:
# C:\Users\rajmu\AppData\Local\Temp\ipykernel_9172\3476352490.py:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   print(tweet.content)
# @modsushi Here you go with Colab notebook:
# How to use OpenAI's Whisper and get word-level timestamps using @DeepgramAI 's API?
#
# And how to generate a subtitle file (.srt) file with word-level timestamps and create Instagram-style fast word-scrolling text videos?
#
# Video tutorial coming soon!
#
# But the code and easy-to-try… https://t.co/tnbbDpyHjF
# @BhosalePratim @yenceesanjeev @nwbotha Thanks, Pratim !
# @savanvyas91 For our apps we use Pinecone with GPT-3 embeddings!
# @savanvyas91 @yenceesanjeev @nwbotha Thank you, Savan!
# 3000$ MRR for Supermeme .ai 🚀
#
# The 0-1 journey from bootstrapping an idea in the mind to sustainable money in the bank is definitely not easy!
#
# But it has been an enjoyable journey because of the rockstar team ⁦@yenceesanjeev⁩
# and ⁦@nwbotha⁩ ! https://t.co/hhs98WkjFl
# @matchaman11 Deepgram has launched a new one!
# As long as you are profitable, almost always focus on business growth.
#
# Quality improvement and cost optimization can be a single API switch whenever you are ready!
#
# 1. GPT-3 -&gt; ChatGPT API
# 2. Whisper API (provider A) -&gt; Whisper API (provider B)
#
# 10x cost reduction and 10x speed… https://t.co/sBhqmGxgLX
# It is magical how robust both LLMs, as well as semantic search systems, are to most typos!
#
# They almost always get my intent and respond back appropriately!
# @savanvyas91 @DeepgramAI Awesome!
# Starting some open-source initiatives from our app Supertranslate .ai
#
# We released hardcoding subtitles  into video with Moviepy
#
# Text motion graphics, smart subtitle splitting, etc in the pipeline of open-source release.
#
# https://t.co/rHfqAHF6RS
# @sachaarbonel @DeepgramAI I don't think so!
# Yesterday @DeepgramAI made two interesting announcements in the speech-to-text world!
#
# 1. Custom OpenAI's Whisper API with built-in speaker diarization and word-level time stamps. This is definitely HUGE!
#
# 2. Their newest model (Nova) for English speech to text that is claimed to… https://t.co/EVnuQ77sGc
# @sandra_rodgers_ @DeepgramAI Hi Sandra! I used OpenAI's whisper in other languages including Hindi and the results are satisfactory.
#
# Sure will explore deepgram as well and keep you posted!
# @DeepgramAI @sandra_rodgers_ Interesting! I shall try it.
# @sandra_rodgers_ @DeepgramAI Thanks a lot, Sandra!  Two quick questions - 1. Are word level time stamps and diarization available for audio in Non-English languages eg: Hindi etc
# 2. Do you support the translation model fo whisper as well? 9Any audio to English)
# @sandra_rodgers_ @DeepgramAI Also
# 2. Do you support the translation mode of Whisper? Any language audio is converted into English in translation mode. Original OpenAI's Whisper supports this mode as well.
# @sandra_rodgers_ @DeepgramAI Thanks a lot, Sandra!
#
# Two quick questions -
# 1. Are word level time stamps and diarization available even if the audio is in Non-English languages eg: Hindi etc
# @DeepgramAI Hi Team,
#
# Where exactly is the API documentation to see how to call Whisper/Nova? I don't seem to see it in your regular developer/api docs.
# @owaisz87 Thank you, Owais :)
# New video on my Youtube channel🔥
#
# Add subtitles permanently to a video using Python and Moviepy
#
# Easy to use Google colab notebook with full code provided!
#
# https://t.co/5SntgtMf6t
# @gurdeep101 I dabbled a bit! Didn't get the vibe! It was a bit complex with local development and I thought I can rather go full JS mode than playing within Pynecone constraints.
# Switched off Twitter and opened TV to catch some fresh air and non AI feed.
#
# But couldn’t! Local TV showed news about an AI created image of how Lord Ram looked when he was 21!
#
# Man! There is no place you can escape to! https://t.co/Lg67SUnMYb
# @alsayed87 Spot on 🚀
# @AbuAbdullah_IN Thanks Abdullah :)
# My genuine state of mind now :)
#
# Especially with weweb new pricing and Flutterflow webapp focused support (besides mobile), it is enticing to find a middle ground than going all in on NextJS and Vercel route! https://t.co/ODRphkppl6
# @LouisSayers Thanks Louis :)
# @jackypan1989 Thanks Jacky :)
# @sergii_shpak @bestbubbledev @NocodeTalks I think @weweb_io and @flutterflow are solid choices for nocode frontend especially that weweb has a new reduced pricing that was announced today.
# @IndianAppGuy Nope. It is combined MRR, not my share!
# If you want to hear everything about my AI SaaS journey in building 3 apps to 4700$ MRR and the broader philosophy around building distribution and finding cofounders, this recent podcast captures most of it :)
# https://t.co/M9jpI74WkO
# @iAbheejit Thanks, Abhijeet :)
# @itsafiz Thank you, Afiz :)
# @_skris Thank you, Sai :)
# Crossed the $10,000 mark on Udemy with my courses :)
#
# I started my AI online teaching journey at the start of 2021 with my first course ever!
#
# Proud that 1000+ paid learners have taken my courses so far :)
#
# From curriculum -&gt; slides -&gt; code notebooks (colab) -&gt; video recordings… https://t.co/ybAzoaHA2X
# @vettukal Thanks Vincent :)
# Friends: Do you really think you will hit that scale with your apps?
#
# Supermeme team: Okay we are approaching 1000 GB hours of execution this month. Time to rethink if we need to host anywhere else :) https://t.co/HExogUkUG7
# The released tutorial:
# https://t.co/y3wv8XVxuY
# After Bubble's pricing changes, many folks want to move to a no-code/low-code frontend with a modern backend like Supabase.
#
# But which low-code platform to choose?
#
# There is no better place than @supabase 's own page on supporting low-code partners :
# https://t.co/Z8FSblEYLX https://t.co/jywAbsOv7u
# When you are in college the next goal is to get a job.
#
# When you are in a job the next goal is to get a top company job.
#
# When you are in a top company job the next goal is to get a top-paying overseas job.
#
# When you are in a top-paying overseas job the next goal is to make the…
# @purnasatyap I tried to address many doubts like background color and text placement position that are not clear from the documentation straightaway.
# @purnasatyap Nice!
# @patloeber 💯
#
# Ps: Your video was the best for me to get started with Supabase and Python!
# New Tutorial 🚀
#
# Permanently Burn Subtitles To a Video Using Python and Moviepy
#
# Code and easy-to-use Google colab Notebook provided!
#
# https://t.co/p96tcvVveB https://t.co/HD6SkmjO6S
# @__ayushsharma I tried it!
# Love it but I found a problem though!
# My medium draft is completely converted into bionic format and looks like I couldn't undo it !
# Had to copy paste text in and out of it again
# @__ayushsharma Nice!
# @IndianAppGuy You can build it but you shouldn't use the word bionic reader.
# Hence my video is titled fast text reader :)
# Want to build your own Bionic fast text reader with Streamlit and Spacy?
#
# Here is my video tutorial with the code :)
#
# https://t.co/mwjNexOWVW https://t.co/LMKiViJ6iW
# @altryne There was no new release for the last 2 years.
# But don't know if it was any official deprecation notice.
# @HussainKhawaja @navift @moinism @Medium Congrats, Hussain!
# How to permanently add (burn) subtitles onto a video using Python and Moviepy?
#
# Tutorial with code coming tomorrow with easy-to-use Google Colab notebook!
#
# Having found no comprehensive resource on the internet that provided a working code for this task, I decided to explore it… https://t.co/AxUoD4WwRo
# @jenny____ai Love it!
# Are these from Midjourney?
# @VisualVichaar Thanks for letting me know!
# @VisualVichaar Oh okay!
# CC: @OfficialLoganK
# How do I access the "browsing" model in ChatGPT?
# I don't seem to find it despite having plugin access :)
# Can someone tell me where is the "browsing" plugin in ChatGPT?
#
# I don't seem to find it although I have plugin access.
# But I have seen others sharing their screenshots with it. https://t.co/Nb7Vy2KQZA
# For every genius who wrote well-commented code at an org that didn’t deploy to production last year, there is an equivalent genius who just deployed the code to production and let GPT-4 catch up later to explain the code to their teammates.  🤯
# @felix_laumann Yes, Felix!
#
# Thank you :)
# No! The media doesn’t write about you!
#
# No! That influencer won’t post about your startup!
#
# No! Your family doesn’t cheer your new beginning!
#
# No! Your friends won’t respond to your ask for introductions.
#
# Yet you remain the warrior with unflinching courage!
#
# You sail, catch some…
# @_raakesh Thanks, Rakesh!
# Reached 200 monthly paying customers across my AI SaaS apps :)
#
# All bootstrapped,  individually profitable, remote, and fractionally operated by the team!
#
# The 150-customer milestone was on Mar 23, 2023!
# The 100-customer milestone was on Feb 7, 2023! https://t.co/vj6D76IjaG
# Can AI be really funny and generate share-worthy memes for real?
#
# Try it out for yourself with our latest algorithm update at Supermeme .ai
#
# Input: "Finding cofounders is really a tough part of the startup journey.  Some find their cofounders in college or among work colleagues.… https://t.co/e8WtGWStAR
# Finding cofounders is really a tough part of the startup journey.
#
# Some find their cofounders in college or among work colleagues.
#
# But the catch is that you mostly hang out with peers with similar skill sets!
#
# Building proof of work online is severely underrated when it comes…
# AI SaaS - Why now?
#
# Here is my recent write up :)
#
# Serverless GPUs, LLMs, and Vector databases are fueling the growth!
# https://t.co/FQuPPOnYxy
# @IndianAppGuy Personally, I love abstractions to move faster.
# But if those abstractions fail to deliver either because of limitations or pricing, time to move on from those abstractions :)
# @iamskaay5 @bhanuv3 @nocodebackend I am evaluating between no-code frontend (Flutterflow) or going the full JS route (NextJS)
#
# A little afraid that if I go the full JS route and learn it in a few months there isn't much in tech left for me to learn ;)
# @bhanuv3 @nocodebackend I am familiar with them.
# Will stick with Supabase as nothing beats it for modern backend.
# At least for me, I am not impressed with Bubble .io and made up my mind to move towards full code or no-code frontend with Supabase backend sooner or later. https://t.co/tIghoTNozb
# @HelperOnly About 70$ each yearly
# @Axel_Paxton Supermeme is at  2500, the highest.
# @YelloowDev About a year!
# @raghavneon Thank you Raghavendran :)
# @_mehul_jain No other team beyond the cofounders. Operating the MicroSaaS way.
#
# Almost primary with courses and consulting augmenting to it.
# @NocodeTalks @bubble I see! Let me double check!
# @adyantalamadhya @_skris Looks like it! I haven't visited them in a long time!
# Met the legendary ⁦@_skris⁩ from Superblog finally 🚀
#
# Met in real life after almost 2 years of knowing him ! https://t.co/n23qsWJpfg
# @NocodeTalks @bubble Bubble plugins internal Stripe customer id and the customer id returned from Stripe after payment
# @NocodeTalks @bubble To the best of my knowledge that id and the id from Bubble aren’t the same. I have to just build outside of the plugins using API connector for Stripe portal access etc. Atleast that is my understanding
# @NocodeTalks @bubble Sure! Will look into it
# @NocodeTalks @bubble For those who subscribed but failed to record in Bubble app, I want to manually enter details and let them open the portal themselves to manage.
# (Stripe Customer Portal Plugin).
# How do I do that?
# What is the equivalent of customer id that can open self service portal?
# Hello @bubble developers!
# How do I retrieve the customer ID that is internally stored in Bubble?
#
# There have been a few cases where customer subscription is successful in Stripe but the DB records etc don't get updated.
#
# How do I manually fill in these values for a customer in… https://t.co/4THHLF74hC
# @A_dot_McKay 1/3rd (1500$) is probably the operating cost.
# @_mehul_jain I have cofounders for two of the apps.
# My portfolio of 3 AI SaaS apps reached 4500$ MRR :)
#
# Text to Meme - Supermeme .ai
# Text to Quiz - Questgen .ai
# Video to subtitles - Supertranslate .ai
# @advany @bubble @supabase @CloudflareDev @weweb_io Let’s look at it this way. If you have 60k views you pay 249 monthly.
#
# And my apps easily are over that limit already. With vercel and supabase we pay a fraction of that cost.
# @advany @bubble @supabase @CloudflareDev @weweb_io I am exactly in the same boat.
# I think weweb is very expensive as well. I am thinking flutterflow as nocode frontend with Supabase backend
# @itsafiz Interesting! I wasn't aware of it! Looks interesting!
# @itsafiz I am exploring automation of text to
# Motion graphics
# @augustoleandro Awesome!
#
# Imagine this -&gt;
# 1. describe what you want in plain text
# 2. LLM maps it to functions
# 2. Movipy renders it.
# @dakshisdaksh Good point.
# Here were my thoughts: I tried to use motion graphics platforms like jitter .video etc
#
# Every time I tried it was incredibly hard to adjust each asset's timing etc. I gave up eventually.
#
# Imagine text to motion graphics.
# Describe what you want in text -&gt; LLM to map it…
# @_Alex_Adamov Haha! Good one buddy :)
# @itsharshag Nice 👌
# Can you do text motion graphics like changing position, scale, rotation, and opacity just with code in Python?
#
# We shall use Moviepy to achieve the same!
#
# Tutorial coming soon! 🚀 https://t.co/L2nHvyMBIl
# @MartinSlaney Thanks Martin!
# If you are a full-stack developer there was no better time to build AI SaaS!
#
# But how do you find ideas with potential?
# Here is my writeup:
#
# https://t.co/vB18y1p64W
# @rachel_l_woods @supermeme_ai Thanks Rachel :)
# @mreflow @jasonvestri You can also look at flutterflow
# @mreflow @jasonvestri Bubble isn’t ideal at all. With new pricing changes it will only cost you more.
# Try framer and beyond that at your scale and traffic self deployment on AWS etc might make more sense if you want to avoid nocode
# @saastrash Haven't watched it but have seen the trailer/promos online!
# Every day an Indian entrepreneur wakes up before dawn ascends a mountain with the highest resistance called family and joins the race with the rest of the world at sunrise.
#
# Truth is harsh, but we cannot deny it!😀
# @NocodeTalks @bhanuv3 Tagging folks who can help/suggest other AI folks
# @NirantK @harishkgarg
# @itsafiz @questgen_ai Thanks Afiz :)
# @bhanuv3 @NocodeTalks I might not have the bandwidth, unfortunately!
# @matchaman11 @questgen_ai Hosting and scaling are a real pain!
# GPT-3/4 does it better and scales seamlessly.
# Updated @questgen_ai to support text up to 2000 words!
#
# The switch to ChatGPT API made it possible to support longer text while keeping the costs in check! https://t.co/n4earLKlAg
# @imakashdesarda :) Thank you!
# Ramsri Goutham Golla: The AI SaaS Mastermind
#
# Follow for
#
# 1) Insights on AI and NLP,
# 2) Knowledge on developing AI SaaS apps,
# 3) Updates on courses at his academy
# Ramsri Goutham Golla, Founder, https://t.co/XlmXWvKEVZ &amp; https://t.co/fctKJTiATb, Interview on Building AI Products https://t.co/L9oTon7wNM
# 20 Inspirational and Motivational Quotes of
# Ramsri Goutham Golla
# Lead Data Scientist, Entrepreneur, Writer
# Hyderabad, Telangana, India
# https://t.co/6rs8dx9BQT
# #inspirationalquotes #inspiration #motivationalquotes #motivation #datascientist #hyderabad
# Exclusive Interview
# Ramsri Goutham Golla
# Lead Data Scientist, Entrepreneur, Writer
# Hyderabad, Telangana, India
# https://t.co/rGBaJVrWrQ
# #interview #gpt3  #ramsrigouthamgolla #nlp #datascience #python #entrepreneur #writer #datascientist #hyderabad #machinelearning #deeplearning
